# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import Markdown

# %%
# Include other necessary imports based on your code's requirements

def to_markdown(text):
    # Simplified indentation (adjust if needed)
    return Markdown(textwrap.indent(text, '  '))  # Two spaces for indentation

# %%
import os
os. environ['GOOGLE_API_KEY']="AIzaSyBOEY5AhqIbAwvg7X0L36J2pL4k0u14KLY"

# %%
genai.configure(api_key="AIzaSyBOEY5AhqIbAwvg7X0L36J2pL4k0u14KLY")

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
for m in genai. list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
genai .GenerativeModel(
model_name= 'models/gemini-pro',
generation_config={},
safety_settings={}
)
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
# %%time
response=model. generate_content("What is the meaning of life")
# Out:
# CPU times: user 2.94 ms, sys: 2.9 ms, total: 5.84 ms
# Wall time: 7.39 s

# %%
# %%time
response=model. generate_content("What is love")
# Out:
# CPU times: user 3.92 ms, sys: 4.35 ms, total: 8.26 ms
# Wall time: 9.97 s

# %%
to_markdown(response.text)
# Out:
#   Love is a complex and multifaceted emotion that has been the subject of much philosophical, psychological, and artistic inquiry throughout history. It is often described as a feeling of deep affection and care for another person, and it can take many different forms, including romantic love, familial love, and platonic love.
#
#   Some of the common characteristics of love include:
#
#   * **Intimacy:** Love involves a sense of closeness and connection with another person. This can be expressed through physical touch, emotional sharing, and mutual understanding.
#   * **Passion:** Love is often associated with a feeling of intense desire or attraction toward another person. This can be expressed through physical intimacy, romantic gestures, or simply spending time together.
#   * **Commitment:** Love often involves a sense of loyalty and commitment to another person. This can be expressed through promises, vows, or simply being there for someone through good times and bad.
# ...

# %%
to_markdown(response.text)
# Out:
#   The meaning of life is a question that has been asked by philosophers, theologians, and ordinary people alike for centuries. There is no one definitive answer, as the meaning of life is likely to be different for each individual. However, there are a few common themes that emerge when people discuss the meaning of life:
#
#   * **Purpose:** Many people find meaning in their lives by pursuing a specific purpose or goal. This could be anything from raising a family to making a difference in the world.
#   * **Relationships:** Strong relationships with family and friends can also provide a sense of meaning and purpose.
#   * **Accomplishment:** Achieving goals and accomplishing things that you are proud of can give you a sense of meaning and satisfaction.
#   * **Experiences:** Having new and interesting experiences can help you to grow as a person and to appreciate the beauty and wonder of the world around you.
# ...

# %%
response.prompt_feedback
# Out:
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }

# %%
response.candidates
# Out:
# [index: 0
# content {
#   parts {
# ...

# %%
for chunk in response:
    print (chunk.text)
    print("_"*80)
# Out:
# Love is a complex and multifaceted emotion that has been the subject of much philosophical, psychological, and artistic inquiry throughout history. It is often described as a feeling of deep affection and care for another person, and it can take many different forms, including romantic love, familial love, and platonic love.
#
# Some of the common characteristics of love include:
#
# * **Intimacy:** Love involves a sense of closeness and connection with another person. This can be expressed through physical touch, emotional sharing, and mutual understanding.
# * **Passion:** Love is often associated with a feeling of intense desire or attraction toward another person. This can be expressed through physical intimacy, romantic gestures, or simply spending time together.
# * **Commitment:** Love often involves a sense of loyalty and commitment to another person. This can be expressed through promises, vows, or simply being there for someone through good times and bad.
# ...

# %%
try:
    response.text
except Exception as e:
    print(f'{type(e)._name_}: (e)')

# %%
import PIL.Image
img = PIL.Image.open('rabbit.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x854>

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
response = model.generate_content (img)
to_markdown (response.text)
# Out:
#    It's a white bunny!
